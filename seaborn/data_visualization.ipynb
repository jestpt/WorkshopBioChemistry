# %%
#######################################################################
############ Statistical Data Visualization with Seaborn ##############
#######################################################################

# More info at: https://seaborn.pydata.org/
# For all the possible plots: https://seaborn.pydata.org/tutorial.html
# Dataset: https://www.kaggle.com/loveall/cervical-cancer-risk-classification/data

# %%
# %matplotlib notebook
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Loading Dataset
dataset = pd.read_csv('../data/cervical_cancer.csv')

list(dataset)

# To view what a variable contains
#print(dataset['Hormonal Contraceptives (years)'])
# Out:
# ['Unnamed: 0',
#  'Age',
#  'Number of sexual partners',
#  'First sexual intercourse',
#  'Num of pregnancies',
#  'Smokes',
#  'Smokes (years)',
#  'Smokes (packs/year)',
#  'Hormonal Contraceptives',
#  'Hormonal Contraceptives (years)',
#  'IUD',
#  'IUD (years)',
#  'STDs',
#  'STDs (number)',
#  'STDs:condylomatosis',
#  'STDs:cervical condylomatosis',
#  'STDs:vaginal condylomatosis',
#  'STDs:vulvo-perineal condylomatosis',
#  'STDs:syphilis',
#  'STDs:pelvic inflammatory disease',
#  'STDs:genital herpes',
#  'STDs:molluscum contagiosum',
#  'STDs:AIDS',
#  'STDs:HIV',
#  'STDs:Hepatitis B',
#  'STDs:HPV',
#  'STDs: Number of diagnosis',
#  'STDs: Time since first diagnosis',
#  'STDs: Time since last diagnosis',
#  'Dx:Cancer',
#  'Dx:CIN',
#  'Dx:HPV',
#  'Dx',
#  'Hinselmann',
#  'Schiller',
#  'Citology',
#  'Biopsy']

# %%
# Visualizing distribution of Age

# Distplot
plt.figure()  # To create a figure
plt.title('Cervical Cancer Distribution by Age')  
sns.distplot(dataset['Age'].loc[dataset['Dx:Cancer'] == 1], color = 'r', bins = 10)
sns.distplot(dataset['Age'].loc[dataset['Dx:Cancer'] == 0], color = 'b', bins = 20)
plt.xlim((0,70))
plt.legend(['Affected by cancer', 'Control'])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Different kinds of data require a different way to visualize them

plt.figure()
plt.title('Distribution of Number of Sexual Partners')
desired_array = dataset['Number of sexual partners'].dropna()
sns.distplot(desired_array, bins = 70)
plt.xlim((0,8))  # We can control the range 
plt.xlabel('Number of sexual partners')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5,0,'Number of sexual partners')

# %%
# Exercício 1
# Display with the sns.distplot() function the distribution of first sexual intercourse
# Hint: Use dropna() to remove any Non-existing values

# %%
# Displaying categorical data

plt.figure()
plt.title('Boxplot of presence of STDs vs Age of first intercourse')
sns.boxplot(x="STDs", y="First sexual intercourse", data = dataset);
#plt.legend(['Affected by cancer', 'Control'])
plt.xlabel('STDs')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5,0,'STDs ')

# %%
# Exercise 2
# Choose two variables you think make the most sense to correlate, and visualize their relationship

# %%
# Visualizing linear relationships

# To note the change of the color palette and markers
sns.lmplot(x='Age', y='First sexual intercourse', hue = 'Dx:Cancer'
           , palette = sns.color_palette('Set1', n_colors=8, desat=.5), data = dataset, markers=['o', 'x'], legend_out = None)
plt.legend(['Affected by cancer', 'Control'])
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
# Exercise 3 (if there's enough time)
# Choose two variables you think make the most sense to correlate, and visualize their relationship
