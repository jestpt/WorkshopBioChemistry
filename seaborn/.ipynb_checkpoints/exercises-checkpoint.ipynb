# %%
# Exercise 1
# Display with the sns.distplot() function the distribution of first sexual intercourse

# %matplotlib notebook
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

dataset = pd.read_csv('../data/cervical_cancer.csv')

plt.figure()
sns.distplot(dataset["First sexual intercourse"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-5e859e3cce9b> in <module>()
#       9
#      10 plt.figure()
# ---> 11 sns.distplot(dataset["First sexual intercourse"])
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     189             line, = ax.plot(0, a.mean())
#     190         else:
# --> 191             line, = ax.plot(a.mean(), 0)
#     192         color = line.get_color()
#     193         line.remove()
#
# ~/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py in _mean(a, axis, dtype, out, keepdims)
#      80             ret = ret.dtype.type(ret / rcount)
#      81     else:
# ---> 82         ret = ret / rcount
#      83
#      84     return ret
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
# Exercise 2
# Display with the sns.barplot() function the relationship between STDs and smoking
# in risk of developing cervical cancer or not

# %matplotlib notebook
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

dataset = pd.read_csv('../data/cervical_cancer.csv')

plt.figure()
plt.title('Relationship between STDs and smoking')
sns.set(color_codes=True)
sns.barplot(x = 'STDs', y = 'Smokes', hue = 'Dx:Cancer', data = dataset);
# Out:
# <img src="data:image/png;base64,..." width="849">
