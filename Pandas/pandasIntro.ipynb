# %%
import pandas as pd
import numpy as np
import random
# %matplotlib inline

# %%
data = pd.read_csv("data/coffees.csv") #tells python to import a csv file
print(type(data))
print(type(data.contributor))  #each column is a pandas Series object
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>

# %%
data
# Out:
#                timestamp  coffees contributor
# 0    2011-10-03 08:22:00    397.0     Quentin
# 1    2011-10-04 11:48:00    410.0     Quentin
# 2    2011-10-05 07:02:00  testing     Anthony
# 3    2011-10-05 08:25:00      NaN     Quentin
# 4    2011-10-05 10:47:00    464.0     Quentin
# 5    2011-10-05 13:15:00    481.0     Quentin
# 6    2011-10-06 07:21:00    503.0     Anthony
# 7    2011-10-06 10:04:00    513.0     Quentin
# 8    2011-10-06 12:14:00    539.0        Mike
# 9    2011-10-06 12:49:00    540.0     Quentin
# 10   2011-10-06 14:52:00    563.0         Ben
# 11   2011-10-07 07:34:00    581.0     Anthony
# 12   2011-10-07 08:37:00    587.0     Quentin
# 13   2011-10-07 11:09:00    605.0     Quentin
# 14   2011-10-07 13:14:00    616.0        Mike
# 15   2011-10-07 14:10:00      NaN         Ben
# 16   2011-10-07 15:20:00    626.0      Mike M
# 17   2011-10-07 16:50:00    635.0      Mike M
# 18   2011-10-09 16:53:00    650.0        Colm
# ...

# %%
data.head()  #shows the first 5 rows by default
#Exe: try n=10
# Out:
#              timestamp  coffees contributor
# 0  2011-10-03 08:22:00    397.0     Quentin
# 1  2011-10-04 11:48:00    410.0     Quentin
# 2  2011-10-05 07:02:00  testing     Anthony
# 3  2011-10-05 08:25:00      NaN     Quentin
# 4  2011-10-05 10:47:00    464.0     Quentin

# %%
data.shape   #result: (rows,columns)
# Out:
# (671, 3)

# %%
data.columns
# Out:
# Index(['timestamp', 'coffees', 'contributor'], dtype='object')

# %%
data.dtypes
# Out:
# timestamp      object
# coffees        object
# contributor    object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 671 entries, 0 to 670
# Data columns (total 3 columns):
# timestamp      671 non-null object
# coffees        658 non-null object
# contributor    671 non-null object
# dtypes: object(3)
# memory usage: 15.8+ KB

# %%
#Like a dictionary, the Series object provides a mapping from a collection of keys to a collection of values
teste = pd.Series(['a', 'b', 'c'], index=[1, 3, 5])
# .loc -->  Purely label-location based indexer for selection by label.
# or
# .iloc  -->  Purely integer-location based indexing for selection by position.
print(teste)
print('.iloc[]: ',teste.iloc[1])
print('.loc[]: ',teste.loc[1])
#what about 3 rows?
# Out:
# 1    a
# 3    b
# 5    c
# dtype: object
# .iloc[]:  b
# .loc[]:  a

# %%
temp=data[['timestamp','coffees','contributor']]

# %%
del temp['coffees']

# %%
temp.head()
# Out:
#              timestamp contributor
# 0  2011-10-03 08:22:00     Quentin
# 1  2011-10-04 11:48:00     Quentin
# 2  2011-10-05 07:02:00     Anthony
# 3  2011-10-05 08:25:00     Quentin
# 4  2011-10-05 10:47:00     Quentin

# %%
data.head()
# Out:
#              timestamp  coffees contributor
# 0  2011-10-03 08:22:00    397.0     Quentin
# 1  2011-10-04 11:48:00    410.0     Quentin
# 2  2011-10-05 07:02:00  testing     Anthony
# 3  2011-10-05 08:25:00      NaN     Quentin
# 4  2011-10-05 10:47:00    464.0     Quentin

# %%
temp['again']=np.random.randint(0,50,size=len(temp))

# %%
temp.iloc[0:5]
# Out:
#              timestamp contributor  again
# 0  2011-10-03 08:22:00     Quentin     16
# 1  2011-10-04 11:48:00     Quentin      0
# 2  2011-10-05 07:02:00     Anthony     19
# 3  2011-10-05 08:25:00     Quentin     14
# 4  2011-10-05 10:47:00     Quentin     37

# %%
temp.dtypes
# Out:
# timestamp      object
# contributor    object
# again           int64
# dtype: object

# %%
temp.timestamp is temp['timestamp']
# Out:
# True

# %%
data.iloc[0, 2] = 90
data
# Out:
#                timestamp  coffees contributor
# 0    2011-10-03 08:22:00    397.0          90
# 1    2011-10-04 11:48:00    410.0     Quentin
# 2    2011-10-05 07:02:00  testing     Anthony
# 3    2011-10-05 08:25:00      NaN     Quentin
# 4    2011-10-05 10:47:00    464.0     Quentin
# 5    2011-10-05 13:15:00    481.0     Quentin
# 6    2011-10-06 07:21:00    503.0     Anthony
# 7    2011-10-06 10:04:00    513.0     Quentin
# 8    2011-10-06 12:14:00    539.0        Mike
# 9    2011-10-06 12:49:00    540.0     Quentin
# 10   2011-10-06 14:52:00    563.0         Ben
# 11   2011-10-07 07:34:00    581.0     Anthony
# 12   2011-10-07 08:37:00    587.0     Quentin
# 13   2011-10-07 11:09:00    605.0     Quentin
# 14   2011-10-07 13:14:00    616.0        Mike
# 15   2011-10-07 14:10:00      NaN         Ben
# 16   2011-10-07 15:20:00    626.0      Mike M
# 17   2011-10-07 16:50:00    635.0      Mike M
# 18   2011-10-09 16:53:00    650.0        Colm
# ...

# %%
data.fillna(method='bfill',axis=0)
# Out:
#                timestamp  coffees contributor
# 0    2011-10-03 08:22:00    397.0          90
# 1    2011-10-04 11:48:00    410.0     Quentin
# 2    2011-10-05 07:02:00  testing     Anthony
# 3    2011-10-05 08:25:00    464.0     Quentin
# 4    2011-10-05 10:47:00    464.0     Quentin
# 5    2011-10-05 13:15:00    481.0     Quentin
# 6    2011-10-06 07:21:00    503.0     Anthony
# 7    2011-10-06 10:04:00    513.0     Quentin
# 8    2011-10-06 12:14:00    539.0        Mike
# 9    2011-10-06 12:49:00    540.0     Quentin
# 10   2011-10-06 14:52:00    563.0         Ben
# 11   2011-10-07 07:34:00    581.0     Anthony
# 12   2011-10-07 08:37:00    587.0     Quentin
# 13   2011-10-07 11:09:00    605.0     Quentin
# 14   2011-10-07 13:14:00    616.0        Mike
# 15   2011-10-07 14:10:00    626.0         Ben
# 16   2011-10-07 15:20:00    626.0      Mike M
# 17   2011-10-07 16:50:00    635.0      Mike M
# 18   2011-10-09 16:53:00    650.0        Colm
# ...
